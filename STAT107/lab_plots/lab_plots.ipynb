# %% [markdown]
# # Welcome to the University of Illinois administrative office!
#
# We are so thankful that you agreed to take a look at our salary data. We have a dataset for you that we need you to perform some analysis on and create some plots that we can show the state to get funding for another year. Further details follow below.
#
# Thanks again!
#
# \- Chancellor Kelly
#
# ## Lab: Plots
#
# In this lab, you will:
#
# - Work with real UIUC salary data to explore some of the statistics that we talked about in class: mean, median, mode, standard deviation, and quartiles!
# - Practice creating plots to visualize quantitative data: boxplots, scatter plots, and histograms

# %% [markdown]
# # 0. Import the Data
#
# In the same directory as this notebook find the dataset that is provided.  You know what to do to import the libraries and read the data! :)

# %%
import pandas as pd
df = pd.read_csv("graybook.csv")
df
# Out:
#                                  Employee Name  Academic Title  \
# 0                              Edakara, Manu I             NaN
# 1                         Quarton, John Edward             NaN
# 2                        Werpetinski, Valeri A             NaN
# 3                   Abdel-Khalik, Ahmed Rashad            PROF
# 4                                 Ahmed, Waqar        LECTURER
# 5                             Anand, Vikrant V       ASST PROF
# 6                          Anderson, Spencer B       ASST PROF
# 7     Augusto Sampaio Franco de Lima, Gerlando     SR LECTURER
# 8                               Brown, Nerissa      ASSOC PROF
# 9                             Brown, Timothy J       ASST PROF
# 10                           Brunner, Robert J            PROF
# 11                           Chatterton, Angel   SR INSTRUCTOR
# 12                              Chen, Ciao-Wei       ASST PROF
# 13                              Chen, Xiaoling            PROF
# 14                            Ciconte, William       ASST PROF
# 15                    Curtis, Susan Mertzlufft        LECTURER
# 16                          Davis, Gregory Lee        LECTURER
# 17                                Davis, Jon S            PROF
# 18                          Donohoe, Michael P      ASSOC PROF
# 19                                     Du, Fei       ASST PROF
# 20                           Elliott, W Brooke            PROF
# 21                       Fanning, Kirsten Beth       ASST PROF
# 22                            Finnegan, Thomas        LECTURER
# 23                          Fisher, Mitchell B      INSTRUCTOR
# 24                           Frizzell, Allyson             NaN
# 25                              Glynn, Amber E             NaN
# 26                              Godsell, David       ASST PROF
# 27                           Hamm, Brian Keith       ASST PROF
# 28                             Hayne, Christie       ASST PROF
# 29                         Hecht, Gary William      ASSOC PROF
# ...                                        ...             ...
# 3525                           Sachdev, Vishal             NaN
# 3526                        Sanders, William H            PROF
# 3527            Santos Gilbertz, Rosa Milagros            PROF
# 3528                        Sather, Carl Allen  CLIN ASST PROF
# 3529                 Savonius-Wroth, Celestina       ASST PROF
# 3530                          Schantz, Susan L            PROF
# 3531                           Schatz, Bruce R            PROF
# 3532                         Schneider, Jodi A       ASST PROF
# 3533                      Seidel, Harry Edward        RES PROF
# 3534                           Smith, Denise L             NaN
# 3535                  Sotomayor Carlo, Antonio       ASST PROF
# 3536                              Sroka, Marek            PROF
# 3537               Stewart de Ramirez, Sarah A      ASSOC PROF
# 3538                         Stodden, Victoria      ASSOC PROF
# 3539                       Szylowicz, Caroline      ASSOC PROF
# 3540                     Tappenden, Kelly Anne            PROF
# 3541                        Tapping, Richard I            PROF
# 3542              Teran-Garcia, Margarita De L   RES ASST PROF
# 3543                           Tilley, Carol L      ASSOC PROF
# 3544             Tussing-Humphreys, Lisa Marie       ASST PROF
# 3545                  Twidale, Michael Bernard            PROF
# 3546                       Von Thaden, Terry L       ASST PROF
# 3547                         Vozenilek, John A            PROF
# 3548                    Weathersby, Deidre Ann  ADJ INSTRUCTOR
# 3549                       Wilson, Barbara Jan            PROF
# 3550                             Wolfson, Ouri            PROF
# 3551                           Wu, Maryalice S   ADJ ASST PROF
# 3552                              Yau, Peter M   RES ASST PROF
# 3553                              Yodh, Jaya G   RES ASST PROF
# 3554                             Zerai, Assata            PROF
#
#                   Primary Job Title Primary College  \
# 0         ASSOC DIR ENTREPRNRL CMTY        Business
# 1      SR DIR INNOVA ENTRPRNRL PRGM        Business
# 2     VST ASSOC DIR, ENTRPRNRL EDUC        Business
# 3                              PROF        Business
# 4                          LECTURER        Business
# 5                         ASST PROF        Business
# 6                         ASST PROF        Business
# 7                       SR LECTURER        Business
# 8                        ASSOC PROF        Business
# 9                         ASST PROF        Business
# 10                             PROF        Business
# 11                    SR INSTRUCTOR        Business
# 12                        ASST PROF        Business
# 13                             PROF        Business
# 14                        ASST PROF        Business
# 15                         LECTURER        Business
# 16                         LECTURER        Business
# 17                             PROF        Business
# 18                       ASSOC PROF        Business
# 19                        ASST PROF        Business
# 20                             PROF        Business
# 21                        ASST PROF        Business
# 22                         LECTURER        Business
# 23                       INSTRUCTOR        Business
# 24                 ACADEMIC ADVISOR        Business
# 25                 ACADEMIC ADVISOR        Business
# 26                        ASST PROF        Business
# 27               CLINICAL ASST PROF        Business
# 28                        ASST PROF        Business
# 29                       ASSOC PROF        Business
# ...                             ...             ...
# 3525                            ???             ???
# 3526                            ???             ???
# 3527                            ???             ???
# 3528                            ???             ???
# 3529                            ???             ???
# 3530                            ???             ???
# 3531                            ???             ???
# 3532                            ???             ???
# 3533                            ???             ???
# 3534                            ???             ???
# 3535                            ???             ???
# 3536                            ???             ???
# 3537                            ???             ???
# 3538                            ???             ???
# 3539                            ???             ???
# 3540                            ???             ???
# 3541                            ???             ???
# 3542                            ???             ???
# 3543                            ???             ???
# 3544                            ???             ???
# 3545                            ???             ???
# 3546                            ???             ???
# 3547                            ???             ???
# 3548                            ???             ???
# 3549                            ???             ???
# 3550                            ???             ???
# 3551                            ???             ???
# 3552                            ???             ???
# 3553                            ???             ???
# 3554                            ???             ???
#
#                   Primary Department     Salary  PrevFTE   FTE  \
# 0     Academy Entrepreneurial Ldrshp   66300.00     1.00  1.00
# 1     Academy Entrepreneurial Ldrshp  150480.70     1.00  1.00
# 2     Academy Entrepreneurial Ldrshp   71400.00     1.00  1.00
# 3                        Accountancy  318007.00     1.00  1.00
# 4                        Accountancy   96691.00     1.00  1.00
# 5                        Accountancy  227553.00     1.00  1.00
# 6                        Accountancy  216342.00     1.00  1.00
# 7                        Accountancy  147900.00     1.00  1.00
# 8                        Accountancy  255000.00     1.00  1.00
# 9                        Accountancy  225000.00     1.00  1.00
# 10                       Accountancy  280000.00     1.00  1.00
# 11                       Accountancy  133869.78     1.00  1.00
# 12                       Accountancy  225000.00     1.00  1.00
# 13                       Accountancy  298098.00     1.00  1.00
# 14                       Accountancy  216465.00     1.00  1.00
# 15                       Accountancy  112241.00     1.00  1.00
# 16                       Accountancy  139679.00     1.00  1.00
# 17                       Accountancy  379962.00     1.00  1.00
# 18                       Accountancy  257500.00     1.00  1.00
# 19                       Accountancy  237500.00     1.00  1.00
# 20                       Accountancy  344073.00     1.00  1.00
# 21                       Accountancy  211064.00     1.00  1.00
# 22                       Accountancy  112290.00     1.00  1.00
# 23                       Accountancy  111609.01     1.00  1.00
# 24                       Accountancy   48426.00     1.00  1.00
# 25                       Accountancy   48909.00     1.00  1.00
# 26                       Accountancy  219300.00     1.00  1.00
# 27                       Accountancy  123250.00     0.85  0.85
# 28                       Accountancy  219300.00     1.00  1.00
# 29                       Accountancy  287500.00     1.00  1.00
# ...                              ...        ...      ...   ...
# 3525                             ???    7500.00     0.00  0.00
# 3526                             ???  387000.00     1.00  0.00
# 3527                             ???  177096.00     0.00  0.00
# 3528                             ???       0.00     0.00  0.00
# 3529                             ???   80627.00     0.00  0.00
# 3530                             ???  151441.58     0.00  0.00
# 3531                             ???  171299.92     0.00  0.00
# 3532                             ???   81148.20     0.00  0.00
# 3533                             ???  395200.00     0.00  0.00
# 3534                             ???   36736.78     0.00  0.00
# 3535                             ???   66776.70     0.00  0.00
# 3536                             ???   92328.65     0.00  0.00
# 3537                             ???  146625.00     0.00  0.00
# 3538                             ???  105286.54     0.00  0.00
# 3539                             ???   72853.05     0.00  0.00
# 3540                             ???  168000.00     0.00  0.00
# 3541                             ???  178000.00     0.00  0.00
# 3542                             ???       0.00     0.00  0.00
# 3543                             ???   89421.49     0.00  0.00
# 3544                             ???  123062.53     0.00  0.00
# 3545                             ???  153413.70     0.00  0.00
# 3546                             ???  110421.71     0.00  0.00
# 3547                             ???   78717.84     0.00  0.00
# 3548                             ???   95981.61     0.00  0.00
# 3549                             ???  459000.00     0.00  0.00
# 3550                             ???  200456.78     0.00  0.00
# 3551                             ???   81962.71     0.00  0.00
# 3552                             ???  131447.50     0.00  0.00
# 3553                             ???  112200.00     0.00  0.00
# 3554                             ???  187530.00     0.00  0.00
#
#                                              All Titles   Empl Class  \
# 0                         ['ASSOC DIR ENTREPRNRL CMTY']       ['BA']
# 1     ['SR DIR INNOVA ENTRPRNRL PRGM' 'DIR HOEFT T&M...       ['BA']
# 2                     ['VST ASSOC DIR, ENTRPRNRL EDUC']       ['BA']
# 3             ['DIR CIERA' 'PROF' 'V K ZIMMERMAN PROF']  ['BC' 'AA']
# 4                                          ['LECTURER']       ['AA']
# 5        ['ASST PROF' 'RC EVANS DATA ANALYTICS FELLOW']       ['AA']
# 6                                         ['ASST PROF']       ['AA']
# 7                                       ['SR LECTURER']       ['AA']
# 8                   ['ASSOC PROF' 'PWC FACULTY FELLOW']       ['AA']
# 9                                         ['ASST PROF']       ['AA']
# 10    ['PROF' 'ARTHUR ANDERSEN FACULTY FELLOW' 'DIR ...  ['AA' 'BA']
# 11     ['ACADEMIC DIR BSA/MAS PROGRAM' 'SR INSTRUCTOR']  ['BA' 'AA']
# 12                                        ['ASST PROF']       ['AA']
# 13    ['DIR PHD PROGRAM' 'FV ROEDGERS FACULTY FELLOW...  ['BC' 'AA']
# 14                                        ['ASST PROF']       ['AA']
# 15                                         ['LECTURER']       ['AA']
# 16                                         ['LECTURER']       ['AA']
# 17              ['PROF' 'ROBERT C EVANS ENDOWED CHAIR']       ['AA']
# 18                  ['ASSOC PROF' 'PWC FACULTY FELLOW']       ['AA']
# 19       ['ASST PROF' 'RC EVANS DATA ANALYTICS FELLOW']       ['AA']
# 20    ['ERNST & YOUNG DIST PROF' 'HEAD ACCOUNTANCY' ...  ['AA' 'BC']
# 21                                        ['ASST PROF']       ['AA']
# 22                                         ['LECTURER']       ['AA']
# 23                                       ['INSTRUCTOR']       ['AA']
# 24                                 ['ACADEMIC ADVISOR']       ['BA']
# 25                                 ['ACADEMIC ADVISOR']       ['BA']
# 26                                        ['ASST PROF']       ['AA']
# 27                               ['CLINICAL ASST PROF']       ['AA']
# 28                                        ['ASST PROF']       ['AA']
# 29    ['ACADEMIC DIR IMSA PRGM' 'ASSOC PROF' 'PWC FA...  ['BA' 'AA']
# ...                                                 ...          ...
# 3525                        ['RC EVANS DATA ANALYTICS']       ['AA']
# 3526                   ['PROF' 'PROF, CSL' 'PROF, ITI']       ['AA']
# 3527                                           ['PROF']       ['AA']
# 3528                                 ['CLIN ASST PROF']       ['AB']
# 3529                                      ['ASST PROF']       ['AA']
# 3530                                           ['PROF']       ['AA']
# 3531                                           ['PROF']       ['AA']
# 3532                               ['ASST PROF, HCESC']       ['AA']
# 3533                 ['RES PROF' 'FOUNDER PROF' 'PROF']       ['AA']
# 3534                                        ['RES SCI']       ['BB']
# 3535                                      ['ASST PROF']       ['AL']
# 3536                                           ['PROF']       ['AA']
# 3537                              ['ASSOC PROF, HCESC']       ['AL']
# 3538                   ['ASSOC PROF' 'ASSOC PROF, CSL']       ['AA']
# 3539                                     ['ASSOC PROF']       ['AL']
# 3540                                           ['PROF']       ['AA']
# 3541                                           ['PROF']       ['AA']
# 3542                                  ['RES ASST PROF']       ['AL']
# 3543                                     ['ASSOC PROF']       ['AA']
# 3544                                      ['ASST PROF']       ['AA']
# 3545                               ['PROF' 'PROF, ITI']       ['AA']
# 3546                                      ['ASST PROF']       ['AA']
# 3547                               ['CLIN PROF, HCESC']       ['AA']
# 3548                                 ['ADJ INSTRUCTOR']       ['AL']
# 3549             ['KATHRYN L B DALLENBACH PROF' 'PROF']       ['AA']
# 3550                                           ['PROF']       ['AA']
# 3551                                  ['ADJ ASST PROF']       ['AA']
# 3552                                  ['RES ASST PROF']       ['AL']
# 3553                                  ['RES ASST PROF']       ['AL']
# 3554                                           ['PROF']       ['AA']
#
#       PrevSalary
# 0       65000.00
# 1      147530.00
# 2       70000.00
# 3      312556.00
# 4       96691.00
# 5      222500.00
# 6      212100.00
# 7      145000.00
# 8      255000.00
# 9      208489.00
# 10     211800.00
# 11     131734.78
# 12     212100.00
# 13     281803.00
# 14     212221.00
# 15     111130.00
# 16     136940.00
# 17     373590.00
# 18     247500.00
# 19     222500.00
# 20     335073.00
# 21     208974.00
# 22     111178.00
# 23     109421.01
# 24      47476.00
# 25      47950.00
# 26     215000.00
# 27     123250.00
# 28     215000.00
# 29     270000.00
# ...          ...
# 3525     7500.00
# 3526   260905.00
# 3527   172777.00
# 3528        0.00
# 3529    78831.20
# 3530   147030.66
# 3531   171196.39
# 3532    79285.00
# 3533   380000.00
# 3534    36016.45
# 3535    65148.00
# 3536    78328.65
# 3537   146625.00
# 3538   103121.00
# 3539    71076.15
# 3540   165000.00
# 3541   176000.00
# 3542        0.00
# 3543    87368.33
# 3544   119885.95
# 3545   149671.90
# 3546   108256.58
# 3547    78185.98
# 3548    92960.40
# 3549   450000.00
# 3550   200456.78
# 3551    80355.60
# 3552   128617.91
# 3553   110000.00
# 3554   184441.29
#
# [3555 rows x 11 columns]

# %% [markdown]
# # 1. The Basics
#
#
# ## Exploring measures of center: Mean, Median, and Standard Deviation
#
# The first thing we need from you is to get us some basics statistics at both a university and department level. We need to know:
# 1. the number of employees at UIUC
# 2. the mean salary
# 3. the median salary
# 4. the standard deviation

# %%
university_num_emp = len(df)
university_num_emp
# Out:
# 3555

# %%
university_mean_sal = df["Salary"].mean()
university_mean_sal
# Out:
# 101284.91668642375

# %%
university_median_sal = df["Salary"].median()
university_median_sal
# Out:
# 86995.0

# %%
university_std_sal = df["Salary"].std()
university_std_sal
# Out:
# 55129.29496464768

# %%
## == TEST CASES for Puzzle 1.1 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.
x = university_num_emp + university_mean_sal + university_median_sal + university_std_sal
y = ((university_mean_sal - university_median_sal) * university_std_sal) / university_num_emp

assert( abs(x - 246964.21165107167) < 1 ), "It looks like your calculations are off?"
assert( abs(y - 221601.415478511) < 1 ), "It looks like your calculations are off?"

# %% [markdown]
# ## Department-level Data
#
# Now we need the same data at a department level. In other words, you want each of those statistics for each department.  There was a certain function you learned a bit ago that will help you **group** all of the people in each department so you can find departmental aggregates.
#
# Instead of just grouping by a single aggregate, use **Python list syntax** to aggregate to find the `count`, `mean`, and `median`.  After that, select only the `'Primary Department'` and `'Salary'` data.
#
# *(You can view technical docs here:
# https://pandas.pydata.org/pandas-docs/stable/reference/groupby.html)*

# %%
group = df.groupby("Primary Department")
agg_df = group["Primary Department", "Salary"].agg(["count", "mean", "median"]).reset_index()




# Display 5 random rows to make sure it works:
agg_df.sample(5)
# Out:
#                  Primary Department Salary
#                                      count           mean     median
# 109                           Music     82   84278.434024  84585.000
# 118                      Psychology     72  105536.000972  88732.625
# 98            Latina/Latino Studies     10   83408.213000  78971.065
# 105        Media and Cinema Studies     13  102675.208462  87423.890
# 97   Latin American & Carib Studies      4   48455.655000  47363.510

# %%
list(agg_df)
# Out:
# [('Primary Department', ''),
#  ('Salary', 'count'),
#  ('Salary', 'mean'),
#  ('Salary', 'median'),
#  ('MedianMulCount', '')]

# %%
## == TEST CASES for Puzzle 1.2 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.
assert( len(agg_df) == 140 ), "You should have 140 different departments.  Check to make sure you grouped the data?"
assert( "Salary" in agg_df ), "You must have a salary output"
assert( "mean" in agg_df["Salary"] ), "Make sure you have a mean in your salary"
assert( "count" in agg_df["Salary"] ), "Make sure you have a count in your salary"
assert( "median" in agg_df["Salary"] ), "Make sure you have a median in your salary"
assert( len(agg_df.columns) == 4 ), "Make sure you have ONLY the salary data and the department"

# %% [markdown]
# Your boss is thrilled with the numbers you've come up with! Now she's ready to go to the state to ask for money. To know how much to ask for, she wants you to **add a column** to the department-grouped DataFrame that is equal to the **median** salary of that department multiplied by the number of people in that department. She wants you to provide her with this table and the sum of all of the values in this column.
#
# Hop to it!

# %%
agg_df['MedianMulCount'] = agg_df[('Salary', 'count')] * agg_df[('Salary', 'median')]


# Display 5 random rows to make sure it works:
agg_df.sample(5)
# Out:
#                 Primary Department Salary                           \
#                                     count           mean    median
# 112    Nuclear, Plasma, & Rad Engr     18  125014.685000  107800.0
# 136                        Theatre     18   76580.444444   76343.5
# 3                      Accountancy     67  188585.546119  210161.0
# 43                Computer Science    105  126891.428571  114277.0
# 82   Human Dvlpmt & Family Studies     43   73734.806047   65149.0
#
#     MedianMulCount
#
# 112      1940400.0
# 136      1374183.0
# 3       14080787.0
# 43      11999085.0
# 82       2801407.0

# %%
# calculate the total sum of all of the values in the column you added
total_money_needed = (agg_df['MedianMulCount']).sum()
total_money_needed
# Out:
# 332199238.08000004

# %%
## == TEST CASES for Puzzle 1.3 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert( abs(total_money_needed - 332199238) < 1 ), "Looks like your multiplication did not work properly!"

# %% [markdown]
# # 2. Estimations
#
# Great! Your boss is ready to go to the state with this number. Is this a good estimate of the amount of money she will need?
#
# Let's calculate the standard deviation for each department to find out.  Remember, SD measures the spread around the average.  The larger the SD, the more spread out the numbers are from the average.
#
# Add another column to your dataframe with the departmental data which holds the value of the standard deviation of the salaries for that department.  *(Hint: This may require you to re-group your original `df`)*

# %%
# add that column here!
agg_df = group["Primary Department", "Salary"].agg(["count", "mean", "median", "std"]).reset_index()



# Display 5 random rows to make sure it works:
agg_df.sample(5)
# Out:
#                  Primary Department Salary                             \
#                                      count           mean      median
# 126  School of Molecular & Cell Bio     26   59050.841538   54912.400
# 10   Agricultural & Biological Engr     29   95750.896207   91342.330
# 52                            Dance     15   81036.752000   81858.280
# 138          Veterinary Prog in Agr      4  148582.230000  149417.760
# 0                               ???    118  154959.069576  120825.305
#
#
#                std
# 126   14302.427072
# 10    35892.681426
# 52    30893.665017
# 138    9930.208707
# 0    115523.851215

# %% [markdown]
# Are there any departments for which your boss' way of approximating the total salary would be fairly accurate? Are there deparments where it would not be an okay approximation?  *Hint*: It might be helpful to find the largest standard deviation!

# %%
list(agg_df)
agg_df.nsmallest(5, [('Salary', 'std')])
# Out:
#                 Primary Department Salary
#                                     count          mean    median          std
# 50  Ctr Wounded Veterans Higher Ed      2  61000.000000  61000.00  1414.213562
# 39  Cline Ctr for Adv Social Rsrch      3  42556.296667  42032.00  1673.229914
# 84         IPM Content Information      2  53106.600000  53106.60  2677.671959
# 97  Latin American & Carib Studies      4  48455.655000  47363.51  4119.849465
# 88                 IPM Development      4  54517.997500  55256.60  6997.587777

# %% [markdown]
# ## EDIT THIS CELL:
#
# - One department where it would be an okay approximation is: Ctr Wounded Veterans Higher Ed	(low standard deviation)
#
# - One department where it would not be an okay approximation is: Entomology (high standard deviation)

# %% [markdown]
# Well, I believe you that the mean salary isn't always a good approximation, but your boss doesn't. I think she is more of a visual learner. To help prove our point, let's make a histogram of the salaries in the computer science department.

# %% [markdown]
# ## 2.1 Histograms
# Create a histogram of the salaries within the computer science department. Pandas has a nice function that helps you accomplish this: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.hist.html
#
# Hint: in order to apply this function, you will need a DataFrame `cs_salary_df` with just the data for Computer Science professors.
#
# Play around with putting different values as the *bin* parameter to the function. Which value would you select to present the data to your boss?  Remember, there is no right or wrong number of bins.  You want to pick an amount that allows you to see the overall shape of the histogram.

# %%
cs_salary_df = df[df["Primary Department"] == "Computer Science"]
cs_salary_df
# ...and then create your histogram:
cs_salary_df.hist(column = "Salary", bins = 10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11eebe208>]],
#       dtype=object)

# %%
## == TEST CASES for Puzzle 2.1 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.
assert(cs_salary_df["Salary"].sum() == 13323600), "You are not showing the correct data in the histogram"

# %% [markdown]
# ## 2.2 Boxplots
#
# Ok, you've convinced her. Your boss no longer thinks that the average is a good approximation for each department. To explain to the state why this isn't the case, she wants you to create a plot that shows the distribution of the salaries for each department that is relatively compact (i.e., not 100 tiny histograms). A collection of box plots would work quite nicely!  This allows us to see different quartiles and if departments have outliers!

# %% [markdown]
# But first, let's just make one box plot. Again, pandas has a nifty function that can help you do this: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.boxplot.html
#
# Make a box plot for the computer science department salaries.

# %%
# Create your box plot of the CS salaries:
cs_salary_df.boxplot("Salary", vert = False)

# %% [markdown]
# # 3. Confronting your boss
# After spending days creating plots, you finally decide to tell your boss that there is an easier way to find out how much money you will need to ask the state for to pay university salaries. Find the exact total amount of money that will be needed to pay everyone in the dataset.

# %%
# your code goes here!
total_money = df["Salary"].sum()
total_money
# Out:
# 358852459.82

# %%
## == TEST CASES for Puzzle 3 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(abs(total_money - 358852459) < 1), "Are you sure the total is correct?"

# %% [markdown]
# ## 4. Your Department
#
# You're awesome!  Now find something interesting about your home department... maybe a box plot or a scatter plot, do whatever interests you, it does not have to be complex (but totally can be!)

# %%
ps_salary_df = df[df["Primary Department"] == "Political Science"]
ps_salary_df.boxplot("Salary", vert = False)
ps_salary_df.hist("Salary", bins = 5)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x120d69b70>]],
#       dtype=object)

# %% [markdown]
# ## Submit Your Work

# %% [markdown]
# You're almost done -- congratulations!
#
# You need to do two more things:
#
# 1. Save your work.  To do this, create a **notebook checkpoint** by using the menu within the notebook to go **File -> Save and Checkpoint**
#
# 2. After you have saved and checkpointed, exit this notebook and return to the Data Science Discovery page on how to use git to turn this notebook into the course!
